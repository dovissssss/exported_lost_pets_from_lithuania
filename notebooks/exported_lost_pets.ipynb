# %%
import pandas as pd

DIRECTORY = "../data/raw/Prarasti_isvezti_augintiniai.csv"

df = pd.read_csv(
    DIRECTORY,
    delimiter=";",
    dtype={" Išvežimo, praradimo pavadinimas": "string", 
           " Šalies pavadinimas": "string", 
           " Gyvūnų augintinio laikymo vietos savivaldybės pavadinimas": "string",
           " Gyvūnų augintinio laikymo vietos seniūnijos pavadinimas": "string", 
           " Gyvūnų augintinio laikymo vietos vietovės pavadinimas": "string",
           " Gyvūno augintinio rūšies pavadinimas": "string", 
           " Išvežimo praradimo metai": "int64", 
           " Gyvūnų augintinių skaičius": "int64"
           })

display(df)
# Out:
#      Išvežimo, praradimo pavadinimas    Šalies pavadinimas  \
# 0                          Išvežimas  NORVEGIJOS KARALYSTĖ
# 1                          Išvežimas    JUNGTINĖ KARALYSTĖ
# 2                          Išvežimas  NORVEGIJOS KARALYSTĖ
# 3                          Išvežimas               UKRAINA
# 4                          Išvežimas    RUSIJOS FEDERACIJA
# ...                              ...                   ...
# 8739                        Dingimas                  <NA>
# 8740                        Dingimas                  <NA>
# 8741                        Dingimas                  <NA>
# 8742                        Dingimas                  <NA>
# 8743                        Dingimas                  <NA>
#
#       Gyvūnų augintinio laikymo vietos savivaldybės pavadinimas  \
# 0                                         Kauno r. sav.
# 1                                       Šiaulių m. sav.
# 2                                         Biržų r. sav.
# ...

# %%
# Exported Pets sum by years, type
df[df["Išvežimo, praradimo pavadinimas"] == "Išvežimas"].groupby([" Išvežimo praradimo metai", " Gyvūno augintinio rūšies pavadinimas"], as_index=False)[" Gyvūnų augintinių skaičius"].sum()
# Out:
#      Išvežimo praradimo metai  Gyvūno augintinio rūšies pavadinimas  \
# 0                        2011                                   Šuo
# 1                        2012                                   Šuo
# 2                        2013                                   Šuo
# 3                        2014                                   Šuo
# 4                        2015                                  Katė
# 5                        2015                                   Šuo
# 6                        2016                                  Katė
# 7                        2016                                Šeškas
# 8                        2016                                   Šuo
# 9                        2017                                  Katė
# 10                       2017                                Šeškas
# 11                       2017                                   Šuo
# 12                       2018                                  Katė
# ...

# %%
# Lost Pets sum by years, type
df[df["Išvežimo, praradimo pavadinimas"] == "Dingimas"].groupby([" Išvežimo praradimo metai", " Gyvūno augintinio rūšies pavadinimas"], as_index=False)[" Gyvūnų augintinių skaičius"].sum()
# Out:
#      Išvežimo praradimo metai  Gyvūno augintinio rūšies pavadinimas  \
# 0                        2015                                   Šuo
# 1                        2016                                  Katė
# 2                        2016                                   Šuo
# 3                        2017                                  Katė
# 4                        2017                                Šeškas
# 5                        2017                                   Šuo
# 6                        2018                                  Katė
# 7                        2018                                Šeškas
# 8                        2018                                   Šuo
# 9                        2019                                  Katė
# 10                       2019                                   Šuo
# 11                       2020                                  Katė
# 12                       2020                                   Šuo
# ...

# %%
# Exported/Lost Pets Total Sum throughout years
df.groupby([" Gyvūno augintinio rūšies pavadinimas", "Išvežimo, praradimo pavadinimas"], as_index=False)[" Gyvūnų augintinių skaičius"].sum()
# Out:
#    Gyvūno augintinio rūšies pavadinimas Išvežimo, praradimo pavadinimas  \
# 0                                  Katė                        Dingimas
# 1                                  Katė                       Išvežimas
# 2                               Triušis                        Dingimas
# 3                                Šeškas                        Dingimas
# 4                                Šeškas                       Išvežimas
# 5                                   Šuo                        Dingimas
# 6                                   Šuo                       Išvežimas
#
#     Gyvūnų augintinių skaičius
# 0                         2156
# 1                         5047
# 2                            1
# 3                           14
# 4                           29
# 5                         2464
# 6                        15206

# %%
# Total exported Pets by export countries
df[df["Išvežimo, praradimo pavadinimas"] == "Išvežimas"].groupby(" Šalies pavadinimas", as_index=False)[" Gyvūnų augintinių skaičius"].sum().sort_values(' Gyvūnų augintinių skaičius', ascending=False)
# Out:
#                    Šalies pavadinimas   Gyvūnų augintinių skaičius
# 87                SUOMIJOS RESPUBLIKA                         2114
# 100  VOKIETIJOS FEDERACINĖ RESPUBLIKA                         1967
# 5                            ANGILIJA                         1691
# 44                 JUNGTINĖ KARALYSTĖ                         1690
# 58                LATVIJOS RESPUBLIKA                         1620
# ..                                ...                          ...
# 21                DOMINIKOS SANDRAUGA                            1
# 25                           ERITRĖJA                            1
# 82           SAUDO ARABIJOS KARALYSTĖ                            1
# 24                EKVADORO RESPUBLIKA                            1
# 77                       PUERTO RIKAS                            1
#
# [106 rows x 2 columns]

# %%
# Lithuanian municipalities by total exported pets sum including all analysis period
df[df["Išvežimo, praradimo pavadinimas"] == "Išvežimas"].groupby(" Gyvūnų augintinio laikymo vietos savivaldybės pavadinimas", as_index=False)[" Gyvūnų augintinių skaičius"].sum().sort_values(' Gyvūnų augintinių skaičius', ascending=False)
# Out:
#     Gyvūnų augintinio laikymo vietos savivaldybės pavadinimas  \
# 48                                   Vilniaus m. sav.
# 14                                      Kauno m. sav.
# 49                                   Vilniaus r. sav.
# 15                                      Kauno r. sav.
# 31                                  Panevėžio m. sav.
# 54                                    Šiaulių m. sav.
# 41                                   Tauragės r. sav.
# 18                                  Klaipėdos m. sav.
# 11                                   Jurbarko r. sav.
# 19                                  Klaipėdos r. sav.
# 13                                    Kalvarijos sav.
# 55                                    Šiaulių r. sav.
# 20                                  Kretingos r. sav.
# 45                                     Utenos r. sav.
# 34                                    Plungės r. sav.
# 35                                     Prienų r. sav.
# ...

# %%
# To how many unique countries, each year pets are exported
df[df["Išvežimo, praradimo pavadinimas"] == "Išvežimas"].groupby(" Išvežimo praradimo metai", as_index=False)[" Šalies pavadinimas"].nunique()
# Out:
#      Išvežimo praradimo metai   Šalies pavadinimas
# 0                        2011                    1
# 1                        2012                    1
# 2                        2013                    1
# 3                        2014                    4
# 4                        2015                    8
# 5                        2016                   51
# 6                        2017                   59
# 7                        2018                   66
# 8                        2019                   65
# 9                        2020                   54
# 10                       2021                   57
# 11                       2022                   69
# 12                       2023                   29

# %%
# Exported Pets sum, max entries and mean entries per year
df[df["Išvežimo, praradimo pavadinimas"] == "Išvežimas"].groupby(" Išvežimo praradimo metai", as_index=False)[" Gyvūnų augintinių skaičius"].agg(['sum', 'max', 'mean'])
# Out:
#                             sum  max      mean
#  Išvežimo praradimo metai
# 2011                          1    1  1.000000
# 2012                          1    1  1.000000
# 2013                          1    1  1.000000
# 2014                          4    1  1.000000
# 2015                         14    4  1.272727
# 2016                       1808   36  2.463215
# 2017                       2535   79  2.584098
# 2018                       2936   46  2.420445
# 2019                       2980   54  2.485405
# 2020                       3847   79  2.832842
# 2021                       4809  248  3.199601
# 2022                       4459  381  3.092233
# 2023                       1522  271  5.141892
