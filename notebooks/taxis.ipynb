# %%
import sys
sys.path.insert(0, "../scripts/")
import seaborn as sns

# %%
from general import assign_trip_duration

# %%
df = sns.load_dataset("taxis")

# %%
df.pipe(assign_trip_duration)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df['pickup'].dt.year.max()
# Out:
# 2019

# %%
df['dropoff'].dt.day.subtract(df['pickup'].dt.day)
# Out:
# 1

# %%
df[['fare', 'tip', 'tolls']].sum(axis=1)
# Out:
# 0        9.15
# 1        5.00
# 2        9.86
# 3       33.15
# 4       10.10
#         ...
# 6428     5.56
# 6429    58.00
# 6430    16.00
# 6431     6.00
# 6432    18.36
# Length: 6433, dtype: float64

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
# Get year and month from pickup_datetime. New columns: year, month
# Was trip a multi year trip? New column: is_multi_year
# Was trip a multi month trip? New column: is_multi_month
# Was trip a multi day trip? New column: is_multi_day
# Combining pickup zone and borough? New column: pickup_zone_borough
# Was person picked up and dropped off in the same zone/borough? New column: is_same_zone_borough
# What colors were tipped the most? Result: Series(color, tip)
# Extract PM and AM from pickup_datetime. New columns: time_of_day
# What duration of trip was PM and AM? Result: Series(time_of_day, duration)
# What was the average tip for each borough? Result: Series(borough, tip)
# What was the average tip for each zone? Result: Series(zone, tip)
# What was the average tip for each borough and zone? Result: Series(borough_zone, tip)
# What columns are categorical? Result: change dtype to category to selecter columns
# What was duration of trip. New column: trip_duration
# Is there correlation between payment and color. Result: Series(color, payment). Run correlation method
# Better names for columns. Result: rename columns

# Check fare, tip, toll and total amount, mismatch? Result: create new column: total_amount_calc and compare with total_amount

# What was the average tip for each borough and zone? Result: Series(borough_zone, tip)
# Split tips to 3 groups: low, medium, high. Each group is 1/3 of total tips. New column: tip_group
# Extract rgb from color. New columns: color_r, color_g, color_b
# Reshape, so that each line would be an event (trip). New columns: event_time, event_type (start, end),

# %%
# Add GIS data
